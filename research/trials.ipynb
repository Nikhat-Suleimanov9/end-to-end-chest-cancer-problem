# %% [markdown]
# ### Downloading the dataset from Google Drive

# %%
import gdown
url = 'https://drive.google.com/file/d/14K9wHmC54zxQrJKf0PJBNF47b2Wwwm42/view?usp=sharing'

# %%
file_id = url.split('/')[-2]

# %%
file_id
# Out:
# '14K9wHmC54zxQrJKf0PJBNF47b2Wwwm42'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "ChestCancer-Dataset(CT).zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=14K9wHmC54zxQrJKf0PJBNF47b2Wwwm42
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=14K9wHmC54zxQrJKf0PJBNF47b2Wwwm42&confirm=t&uuid=b3d46b2b-1c6d-48a9-a35e-e3047b67c9ae
# To: d:\end-to-end-chest-cancer-problem\research\ChestCancer-Dataset(CT).zip
# 100%|██████████| 77.6M/77.6M [00:31<00:00, 2.45MB/s]
# 'ChestCancer-Dataset(CT).zip'
