# %%
import os
# %pwd
os.chdir("../")

# %%
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
import os




class PredictionPipeline:
    def __init__(self,filename):
        self.filename =filename

    
    def predict(self):
        #model = load_model(os.path.join("artifacts","training","trained_model.h5"))
        model = load_model(os.path.join("model","trained_model.h5"))
        model.load_weights("artifacts/training/trained_model.h5")
        
        imagename = self.filename
        test_image = image.load_img(imagename, target_size = (224,224))
        test_image = image.img_to_array(test_image)
        test_image = np.expand_dims(test_image, axis = 0)
        result = np.argmax(model.predict(test_image), axis=1)
        print(result)


        if result[0] == 0:
            prediction = 'adenocarcinoma'
            return [{'image': prediction }]
        elif result[0] == 1:
            prediction = 'large.cell.carcinoma'
            return [{'image': prediction }]
        elif result[0] == 2:
            prediction = 'Normal'
            return [{'image': prediction }]
        elif result[0] == 3:
            prediction = 'squamous.cell.carcinoma'
            return [{'image': prediction }]

# %%
image_path = "artifacts/data_ingestion/Chest_cancer/test/adenocarcinoma/000114.png"  # change this path

predictor = PredictionPipeline(image_path)
result = predictor.predict()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 4
#       1 image_path = "artifacts/data_ingestion/Chest_cancer/test/adenocarcinoma/000114.png"  # change this path
#       3 predictor = PredictionPipeline(image_path)
# ----> 4 result = predictor.predict()
#
# Cell In[26], line 15, in PredictionPipeline.predict(self)
#      14 def predict(self):
# ---> 15     model = load_model(os.path.join("artifacts","training","trained_model.h5"))
#      16     #model = load_model(os.path.join("model","trained_model.h5"))
#      19     imagename = self.filename
#
# File d:\anaconda\envs\canCHE\lib\site-packages\keras\saving\saving_api.py:212, in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     204     return saving_lib.load_model(
#     205         filepath,
#     206         custom_objects=custom_objects,
#     207         compile=compile,
# ...

# %%
print(result)
# Out:
# [{'image': 'Normal'}]

# %%
result
# Out:
# [{'image': 'Normal'}]

# %%
result = np.argmax([[0, 0, 1, 0]], axis=1)

result[0]
# Out:
# 2
